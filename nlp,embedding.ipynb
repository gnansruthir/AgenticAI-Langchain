# %%
! pip install kagglehub
# Out:
# Collecting kagglehub
#   Downloading kagglehub-1.0.1-py3-none-any.whl.metadata (40 kB)
# Requirement already satisfied: kagglesdk<1.0,>=0.1.22 in c:\users\gnansruthi\anaconda3\lib\site-packages (from kagglehub) (0.1.23)
# Requirement already satisfied: packaging in c:\users\gnansruthi\anaconda3\lib\site-packages (from kagglehub) (24.1)
# Requirement already satisfied: pyyaml in c:\users\gnansruthi\anaconda3\lib\site-packages (from kagglehub) (6.0.1)
# Requirement already satisfied: requests in c:\users\gnansruthi\anaconda3\lib\site-packages (from kagglehub) (2.32.3)
# Requirement already satisfied: tqdm in c:\users\gnansruthi\anaconda3\lib\site-packages (from kagglehub) (4.66.5)
# Requirement already satisfied: protobuf in c:\users\gnansruthi\anaconda3\lib\site-packages (from kagglesdk<1.0,>=0.1.22->kagglehub) (7.35.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\gnansruthi\anaconda3\lib\site-packages (from requests->kagglehub) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\gnansruthi\anaconda3\lib\site-packages (from requests->kagglehub) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\gnansruthi\anaconda3\lib\site-packages (from requests->kagglehub) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\gnansruthi\anaconda3\lib\site-packages (from requests->kagglehub) (2025.1.31)
# Requirement already satisfied: colorama in c:\users\gnansruthi\anaconda3\lib\site-packages (from tqdm->kagglehub) (0.4.6)
# Downloading kagglehub-1.0.1-py3-none-any.whl (70 kB)
# Installing collected packages: kagglehub
# Successfully installed kagglehub-1.0.1
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x0000021AED78F470>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /simple/kagglehub/
# WARNING: Retrying (Retry(total=3, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='pypi.org', port=443): Read timed out. (read timeout=15)")': /simple/kagglehub/
# WARNING: Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='pypi.org', port=443): Read timed out. (read timeout=15)")': /simple/kagglehub/
# WARNING: Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='pypi.org', port=443): Read timed out. (read timeout=15)")': /simple/kagglehub/
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='files.pythonhosted.org', port=443): Read timed out. (read timeout=15)")': /packages/70/14/7b1f40778a4c8930f46b5841902647396069ccaa21cb8e0779ee822ffa77/kagglehub-1.0.1-py3-none-any.whl

# %%
import kagglehub
uciml_sms_spam_collection_dataset_path = kagglehub.dataset_download('uciml/sms-spam-collection-dataset')
danielwillgeorge_glove6b100dtxt_path = kagglehub.dataset_download('danielwillgeorge/glove6b100dtxt')
andreshg_masksforwordclouds_path = kagglehub.dataset_download('andreshg/masksforwordclouds')
image_source = kagglehub.dataset_download("andreshg/masksforwordclouds")

print('Data source import complete.')
# Out:
# Downloading to C:\Users\gnansruthi\.cache\kagglehub\datasets\uciml\sms-spam-collection-dataset\1.archive...
# 100%|██████████| 211k/211k [00:00<00:00, 223kB/s]
# Extracting files...
# Downloading to C:\Users\gnansruthi\.cache\kagglehub\datasets\danielwillgeorge\glove6b100dtxt\1.archive...
#  99%|█████████▉| 130M/131M [14:53<00:10, 153kB/s]
# ---------------------------------------------------------------------------
# IncompleteRead                            Traceback (most recent call last)
# File c:\Users\gnansruthi\anaconda3\Lib\site-packages\urllib3\response.py:748, in HTTPResponse._error_catcher(self)
#     747 try:
# --> 748     yield
#     750 except SocketTimeout as e:
#     751     # FIXME: Ideally we'd like to include the url in the ReadTimeoutError but
#     752     # there is yet no clean way to get at it from this context.
#
# File c:\Users\gnansruthi\anaconda3\Lib\site-packages\urllib3\response.py:894, in HTTPResponse._raw_read(self, amt, read1)
#     884     if (
#     885         self.enforce_content_length
#     886         and self.length_remaining is not None
#    (...)
#     892         # raised during streaming, so all calls with incorrect
#     893         # Content-Length are caught.
# --> 894         raise IncompleteRead(self._fp_bytes_read, self.length_remaining)
#     895 elif read1 and (
#     896     (amt != 0 and not data) or self.length_remaining == len(data)
#     897 ):
#    (...)
#     900     # `http.client.HTTPResponse`, so we close it here.
#     901     # See https://github.com/python/cpython/issues/113199
#
# IncompleteRead: IncompleteRead(137153140 bytes read, 694511 more expected)
#
# The above exception was the direct cause of the following exception:
#
# ProtocolError                             Traceback (most recent call last)
# File c:\Users\gnansruthi\anaconda3\Lib\site-packages\requests\models.py:820, in Response.iter_content.<locals>.generate()
#     819 try:
# --> 820     yield from self.raw.stream(chunk_size, decode_content=True)
#     821 except ProtocolError as e:
#
# File c:\Users\gnansruthi\anaconda3\Lib\site-packages\urllib3\response.py:1060, in HTTPResponse.stream(self, amt, decode_content)
#    1059 while not is_fp_closed(self._fp) or len(self._decoded_buffer) > 0:
# -> 1060     data = self.read(amt=amt, decode_content=decode_content)
#    1062     if data:
#
# File c:\Users\gnansruthi\anaconda3\Lib\site-packages\urllib3\response.py:977, in HTTPResponse.read(self, amt, decode_content, cache_content)
#     973 while len(self._decoded_buffer) < amt and data:
#     974     # TODO make sure to initially read enough data to get past the headers
#     975     # For example, the GZ file header takes 10 bytes, we don't want to read
#     976     # it one byte at a time
# --> 977     data = self._raw_read(amt)
#     978     decoded_data = self._decode(data, decode_content, flush_decoder)
#
# File c:\Users\gnansruthi\anaconda3\Lib\site-packages\urllib3\response.py:872, in HTTPResponse._raw_read(self, amt, read1)
#     870 fp_closed = getattr(self._fp, "closed", False)
# --> 872 with self._error_catcher():
#     873     data = self._fp_read(amt, read1=read1) if not fp_closed else b""
#
# File c:\Users\gnansruthi\anaconda3\Lib\contextlib.py:158, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     157 try:
# --> 158     self.gen.throw(value)
#     159 except StopIteration as exc:
#     160     # Suppress StopIteration *unless* it's the same exception that
#     161     # was passed to throw().  This prevents a StopIteration
#     162     # raised inside the "with" statement from being suppressed.
#
# File c:\Users\gnansruthi\anaconda3\Lib\site-packages\urllib3\response.py:772, in HTTPResponse._error_catcher(self)
#     771         arg = f"Connection broken: {e!r}"
# --> 772     raise ProtocolError(arg, e) from e
#     774 except (HTTPException, OSError) as e:
#
# ProtocolError: ('Connection broken: IncompleteRead(137153140 bytes read, 694511 more expected)', IncompleteRead(137153140 bytes read, 694511 more expected))
#
# During handling of the above exception, another exception occurred:
#
# ChunkedEncodingError                      Traceback (most recent call last)
# Cell In[3], line 3
#       1 import kagglehub
#       2 uciml_sms_spam_collection_dataset_path = kagglehub.dataset_download('uciml/sms-spam-collection-dataset')
# ----> 3 danielwillgeorge_glove6b100dtxt_path = kagglehub.dataset_download('danielwillgeorge/glove6b100dtxt')
#       4 andreshg_masksforwordclouds_path = kagglehub.dataset_download('andreshg/masksforwordclouds')
#       5 image_source = kagglehub.dataset_download("andreshg/masksforwordclouds")
#
# File c:\Users\gnansruthi\anaconda3\Lib\site-packages\kagglehub\datasets.py:52, in dataset_download(handle, path, force_download, output_dir)
#      50 h = parse_dataset_handle(handle)
#      51 logger.info(f"Downloading Dataset: {h.to_url()} ...", extra={**EXTRA_CONSOLE_BLOCK})
# ---> 52 resolved_path, _ = registry.dataset_resolver(
#      53     h,
#      54     path,
#      55     force_download=force_download,
#      56     output_dir=output_dir,
#      57 )
#      58 return resolved_path
#
# File c:\Users\gnansruthi\anaconda3\Lib\site-packages\kagglehub\registry.py:28, in MultiImplRegistry.__call__(self, *args, **kwargs)
#      26 for impl in reversed(self._impls):
#      27     if impl.is_supported(*args, **kwargs):
# ---> 28         return impl(*args, **kwargs)
#      29     else:
#      30         fails.append(type(impl).__name__)
#
# File c:\Users\gnansruthi\anaconda3\Lib\site-packages\kagglehub\resolver.py:35, in Resolver.__call__(self, handle, path, force_download, output_dir)
#      15 def __call__(
#      16     self,
#      17     handle: T,
#    (...)
#      21     output_dir: str | None = None,
#      22 ) -> tuple[str, int | None]:
#      23     """Resolves a handle into a path with the requested file(s) and the resource's version number.
#      24
#      25     Args:
#    (...)
#      33         Some cases where version number might be missing: Competition datasource, API-based models.
#      34     """
# ---> 35     path, version = self._resolve(
#      36         handle,
#      37         path,
#      38         force_download=force_download,
#      39         output_dir=output_dir,
#      40     )
#      42     # Note handles are immutable, so _resolve() could not have altered our reference
#      43     register_datasource_access(handle, version)
#
# File c:\Users\gnansruthi\anaconda3\Lib\site-packages\kagglehub\http_resolver.py:154, in DatasetHttpResolver._resolve(self, h, path, force_download, output_dir)
#     152 # First, we download the archive.
#     153 response = handle_call(lambda: api_client.datasets.dataset_api_client.download_dataset(r), h)
# --> 154 download_file(response, archive_path, h)
#     156 _extract_archive(archive_path, out_path)
#     158 # Delete the archive
#
# File c:\Users\gnansruthi\anaconda3\Lib\site-packages\kagglehub\clients.py:202, in download_file(response, out_file, resource_handle, cached_path, extract_auto_compressed_file)
#     200 else:
#     201     logger.info(f"Downloading to {out_file}...")
# --> 202     _download_file(response, out_file, size_read, total_size, hash_object)
#     204 if hash_object:
#     205     actual_md5_hash = to_b64_digest(hash_object)
#
# File c:\Users\gnansruthi\anaconda3\Lib\site-packages\kagglehub\clients.py:246, in _download_file(response, out_file, size_read, total_size, hash_object)
#     244 with tqdm(total=total_size, initial=size_read, unit="B", unit_scale=True, unit_divisor=1024) as progress_bar:
#     245     with open(out_file, open_mode) as f:
# --> 246         for chunk in response.iter_content(CHUNK_SIZE):
#     247             f.write(chunk)
#     248             if hash_object:
#
# File c:\Users\gnansruthi\anaconda3\Lib\site-packages\requests\models.py:822, in Response.iter_content.<locals>.generate()
#     820     yield from self.raw.stream(chunk_size, decode_content=True)
#     821 except ProtocolError as e:
# --> 822     raise ChunkedEncodingError(e)
#     823 except DecodeError as e:
#     824     raise ContentDecodingError(e)
#
# ChunkedEncodingError: ('Connection broken: IncompleteRead(137153140 bytes read, 694511 more expected)', IncompleteRead(137153140 bytes read, 694511 more expected))
