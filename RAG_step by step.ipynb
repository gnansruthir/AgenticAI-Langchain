# %% [markdown]
# ### rag step by step
# topics covered
#  create a simple doc
#  chunking
#  embedding
#  and so on

# %%
document = '''
Ai is transforming education
and helps to reduce wasting time
'''
print(document)
# Out:
# Ai is transforming education
# and helps to reduce wasting time

# %% [markdown]
# ### chuncking- fullstop it seperates the sentences

# %%
text = '''
Ai is transforming education.
and helps to reduce wasting time.
'''
chunks = text.split(".")
print(chunks)
# Out:
# ['\nAi is transforming education', '\nand helps to reduce wasting time', '\n']

# %% [markdown]
# ### remove empty chunks- / removal

# %%
chunks=[chunk.strip() for chunk in chunks if chunk.strip()]
print(chunks)
# Out:
# ['Ai is transforming education', 'and helps to reduce wasting time']

# %% [markdown]
# ### install sentence transformers

# %%
! pip install sentence-transformers
# Out:
# ^C
# ERROR: Exception:
# Traceback (most recent call last):
#   File "c:\Users\gnansruthi\anaconda3\Lib\site-packages\pip\_vendor\urllib3\response.py", line 438, in _error_catcher
#     yield
#   File "c:\Users\gnansruthi\anaconda3\Lib\site-packages\pip\_vendor\urllib3\response.py", line 561, in read
#     data = self._fp_read(amt) if not fp_closed else b""
#            ^^^^^^^^^^^^^^^^^^
#   File "c:\Users\gnansruthi\anaconda3\Lib\site-packages\pip\_vendor\urllib3\response.py", line 527, in _fp_read
#     return self._fp.read(amt) if amt is not None else self._fp.read()
#            ^^^^^^^^^^^^^^^^^^
#   File "c:\Users\gnansruthi\anaconda3\Lib\site-packages\pip\_vendor\cachecontrol\filewrapper.py", line 98, in read
#     data: bytes = self.__fp.read(amt)
#                   ^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\gnansruthi\anaconda3\Lib\http\client.py", line 479, in read
#     s = self.fp.read(amt)
#         ^^^^^^^^^^^^^^^^^
# ...
