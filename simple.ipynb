# %%
import numpy as np ##linear algebra
import pandas as pd ##data processing,data transformation,data cleaning,csv file I/O 
from sklearn.linear_model import LinearRegression ## used to perform linear regression 
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error,r2_score,mean_absolute_error,mean_absolute_percentage_error

# %% [markdown]
# # gathering all data into dataframe

# %%
df = pd.read_csv("C:/Users/gnansruthi/OneDrive/Desktop/AgenticAI/salary_dataset.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       30 non-null     int64
#  1   YearsExperience  30 non-null     float64
#  2   Salary           30 non-null     float64
# dtypes: float64(2), int64(1)
# memory usage: 852.0 bytes

# %%
df.head()
# Out:
#    Unnamed: 0  YearsExperience   Salary
# 0           0              1.2  39344.0
# 1           1              1.4  46206.0
# 2           2              1.6  37732.0
# 3           3              2.1  43526.0
# 4           4              2.3  39892.0

# %%
df.isnull().sum()
# Out:
# Unnamed: 0         0
# YearsExperience    0
# Salary             0
# dtype: int64

# %%
df.describe()
# Out:
#        Unnamed: 0  YearsExperience         Salary
# count   30.000000        30.000000      30.000000
# mean    14.500000         5.413333   76004.000000
# std      8.803408         2.837888   27414.429785
# min      0.000000         1.200000   37732.000000
# 25%      7.250000         3.300000   56721.750000
# 50%     14.500000         4.800000   65238.000000
# 75%     21.750000         7.800000  100545.750000
# max     29.000000        10.600000  122392.000000

# %% [markdown]
# # defining the feature(x),target(y)

# %%
X = df.drop(['Salary','Unnamed: 0'],axis=1) ##features
Y = df["Salary"] ##target var

# %% [markdown]
# # spliting the dataset into traininf ans testing part

# %%
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.2, random_state=42)

# %%
X_train.shape
# Out:
# (24, 1)

# %%
Y_train.shape
# Out:
# (24,)

# %%
X_test.shape
# Out:
# (6, 1)

# %%
Y_test.shape
# Out:
# (6,)

# %% [markdown]
# # model seclection

# %%
model = LinearRegression()

# %% [markdown]
# # train linear regression model

# %%
model = model.fit(X_train,Y_train)

# %% [markdown]
# # predict value from model

# %%
predictedSalary = model.predict(X_test)

# %%
predictedSalary
# Out:
# array([115791.21011287,  71499.27809463, 102597.86866063,  75268.80422384,
#         55478.79204548,  60190.69970699])

# %% [markdown]
# # compare predicted value with og value(y_test)

# %%
errors = mean_squared_error(Y_test, predictedSalary)
print("mse:",errors)
r2 = r2_score(Y_test,predictedSalary)
print("r2:",r2)
mae = mean_absolute_error(Y_test,predictedSalary)
print("mae:",mae)
mape = mean_absolute_percentage_error(Y_test, predictedSalary)
print("mape:",mape)
# Out:
# mse: 49830096.855908334
# r2: 0.9024461774180498
# mae: 6286.453830757745
# mape: 0.0774477845982914

# %% [markdown]
# # visualize estimated the best fit line for model

# %%
plt.scatter(X,Y, color='blue')
plt.plot(X, model.predict(X),color='red')
