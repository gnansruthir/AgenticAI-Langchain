# %% [markdown]
# # Machine learning basics

# %%
print("hello")
# Out:
# hello

# %% [markdown]
# # Types of ML Models
# - regression
# - classification
# - clustering

# %% [markdown]
# #  Regression
# ### To predict continuous linear values from the given data
# Steps:
# 1. Import the required libraries
# 2. Gather all the required data
# -------------------------------------------------------------------------------------------------------------------------------------------
# 2. Defines feature(X) and target(Y)
# 3. Splitting data into training and testing dataset.
# 4. Use traininf data to train the model
# 5. use testing data to test model performance
# 6. Visualize the final model

# %% [markdown]
# # step1. importing the required libraries

# %%
! pip install numpy pandas scikit-learn matplotlib

# %%
import numpy as np ##linear algebra
import pandas as pd ##data processing,data transformation,data cleaning,csv file I/O 
from sklearn.linear_model import LinearRegression ## used to perform linear regression 
import matplotlib.pyplot as plt ##used to plot data
## not required for linear regression 
## from sklearn,model_selection import train_test_split
## import tensorflow as tf
## import seaborn as sea
## import plotly as py

# %% [markdown]
# # experimenting with random data

# %%
# %matplotlib inline
## import matplotlib.pyplot as plt
plt.style.use('ggplot')
## import numpy as np

# %%
randomdata = np.random.RandomState(1)
x = 10 * randomdata.rand(50)
y = x-1+randomdata.rand(50)
plt.scatter(x,y)
plt.show()

# %%
model = LinearRegression()
model.fit(x[:, np.newaxis], y)

xfit = np.linspace(0, 10, 100)
yfit = model.predict(xfit[:, np.newaxis])
plt.scatter(x, y)
plt.plot(xfit, yfit, color='green')
plt.show()
